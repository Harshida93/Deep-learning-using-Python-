# %%
pip install wikipedia-api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wikipediaapi

# %%
wiki_wiki = wikipediaapi.Wikipedia('en')

# %%
page_py = wiki_wiki.page('George W. Bush')

# %%
print("Page - Exists: %s" % page_py.exists())
# Out:
# Page - Exists: True

# %%
print("Page - Title: %s" % page_py.title)
# Out:
# Page - Title: George W. Bush

# %%
print("Page - Summary: %s" % page_py.summary)
# Out:
# Page - Summary: George Walker Bush (born July 6, 1946) is an American politician and businessman who served as the 43rd president of the United States from 2001 to 2009. He had previously served as the 46th governor of Texas from 1995 to 2000.
# ...

# %%
#1

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
SummaryData=page_py.summary

# %%
SummaryData
# Out:
# 'George Walker Bush (born July 6, 1946) is an American politician and businessman who served as the 43rd president of the United States from 2001 to 2009. He had previously served as the 46th governor of Texas from 1995 to 2000.\nBush was born in New Haven, Connecticut, and grew up in Texas. After graduating from Yale University in 1968 and Harvard Business School in 1975, he worked in the oil industry. Bush married Laura Welch in 1977 and unsuccessfully ran for the U.S. House of Representatives shortly thereafter. He later co-owned the Texas Rangers baseball team before defeating Ann Richards in the 1994 Texas gubernatorial election. Bush was elected President of the United States in 2000 when he defeated Democratic incumbent Vice President Al Gore after a close and controversial win that involved a stopped recount in Florida. He became the fourth person to be elected president while receiving fewer popular votes than his opponent. Bush is a member of a prominent political family an
# ...

# %%
FullContent=page_py.text

# %%
#1

# %%
word_list=word_tokenize(SummaryData)
word_list1=word_tokenize(FullContent)

# %%
word_list
# Out:
# ['George',
#  'Walker',
#  'Bush',
#  '(',
#  'born',
#  'July',
#  '6',
#  ',',
#  '1946',
#  ')',
#  'is',
#  'an',
#  'American',
#  'politician',
#  'and',
#  'businessman',
#  'who',
#  'served',
#  'as',
#  'the',
#  '43rd',
#  'president',
#  'of',
#  'the',
#  'United',
#  'States',
#  'from',
#  '2001',
#  'to',
#  '2009',
#  '.',
#  'He',
#  'had',
#  'previously',
#  'served',
#  'as',
#  'the',
#  '46th',
#  'governor',
#  'of',
#  'Texas',
#  'from',
#  '1995',
#  'to',
#  '2000',
#  '.',
#  'Bush',
#  'was',
#  'born',
#  'in',
#  'New',
#  'Haven',
#  ',',
#  'Connecticut',
#  ',',
#  'and',
#  'grew',
#  'up',
#  'in',
#  'Texas',
#  '.',
#  'After',
#  'graduating',
#  'from',
#  'Yale',
#  'University',
#  'in',
#  '1968',
#  'and',
#  'Harvard',
#  'Business',
#  'School',
#  'in',
#  '1975',
#  ',',
#  'he',
#  'worked',
#  'in',
#  'the',
#  'oil',
#  'industry',
#  '.',
#  'Bush',
#  'married',
#  'Laura',
#  'Welch',
#  'in',
#  '1977',
#  'and',
# ...

# %%
word_list1
# Out:
# ['George',
#  'Walker',
#  'Bush',
#  '(',
#  'born',
#  'July',
#  '6',
#  ',',
#  '1946',
#  ')',
#  'is',
#  'an',
#  'American',
#  'politician',
#  'and',
#  'businessman',
#  'who',
#  'served',
#  'as',
#  'the',
#  '43rd',
#  'president',
#  'of',
#  'the',
#  'United',
#  'States',
#  'from',
#  '2001',
#  'to',
#  '2009',
#  '.',
#  'He',
#  'had',
#  'previously',
#  'served',
#  'as',
#  'the',
#  '46th',
#  'governor',
#  'of',
#  'Texas',
#  'from',
#  '1995',
#  'to',
#  '2000',
#  '.',
#  'Bush',
#  'was',
#  'born',
#  'in',
#  'New',
#  'Haven',
#  ',',
#  'Connecticut',
#  ',',
#  'and',
#  'grew',
#  'up',
#  'in',
#  'Texas',
#  '.',
#  'After',
#  'graduating',
#  'from',
#  'Yale',
#  'University',
#  'in',
#  '1968',
#  'and',
#  'Harvard',
#  'Business',
#  'School',
#  'in',
#  '1975',
#  ',',
#  'he',
#  'worked',
#  'in',
#  'the',
#  'oil',
#  'industry',
#  '.',
#  'Bush',
#  'married',
#  'Laura',
#  'Welch',
#  'in',
#  '1977',
#  'and',
# ...

# %%
#2

# %%
SummaryDataL=SummaryData.lower()

# %%
FullContentL=FullContent.lower()

# %%
word_list=word_tokenize(SummaryDataL)
word_list1=word_tokenize(FullContentL)

# %%
#3

# %%
from nltk.corpus import stopwords

# %%
Stop_words=set(stopwords.words("english"))

# %%
Stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
StopWords_removed=[i for i in word_list if not i in Stop_words]

# %%
StopWords_removed
# Out:
# ['george',
#  'walker',
#  'bush',
#  '(',
#  'born',
#  'july',
#  '6',
#  ',',
#  '1946',
#  ')',
#  'american',
#  'politician',
#  'businessman',
#  'served',
#  '43rd',
#  'president',
#  'united',
#  'states',
#  '2001',
#  '2009.',
#  'previously',
#  'served',
#  '46th',
#  'governor',
#  'texas',
#  '1995',
#  '2000.',
#  'bush',
#  'born',
#  'new',
#  ',',
#  'connecticut',
#  ',',
#  'grew',
#  'texas',
#  '.',
#  'graduating',
#  'yale',
#  'university',
#  '1968',
#  'harvard',
#  'business',
#  'school',
#  '1975',
#  ',',
#  'worked',
#  'oil',
#  'industry',
#  '.',
#  'bush',
#  'married',
#  'laura',
#  'welch',
#  '1977',
#  'unsuccessfully',
#  'ran',
#  'u.s.',
#  'house',
#  'representatives',
#  'shortly',
#  'thereafter',
#  '.',
#  'later',
#  'co-owned',
#  'texas',
#  'rangers',
#  'baseball',
#  'team',
#  'defeating',
#  'ann',
#  'richards',
#  '1994',
#  'texas',
#  'gubernatorial',
#  'election',
#  '.',
#  'bush',
#  'elected',
#  'president',
# ...

# %%
StopWords_removed1=[i for i in word_list1 if not i in Stop_words]

# %%
StopWords_removed1
# Out:
# ['george',
#  'walker',
#  'bush',
#  '(',
#  'born',
#  'july',
#  '6',
#  ',',
#  '1946',
#  ')',
#  'american',
#  'politician',
#  'businessman',
#  'served',
#  '43rd',
#  'president',
#  'united',
#  'states',
#  '2001',
#  '2009.',
#  'previously',
#  'served',
#  '46th',
#  'governor',
#  'texas',
#  '1995',
#  '2000.',
#  'bush',
#  'born',
#  'new',
#  ',',
#  'connecticut',
#  ',',
#  'grew',
#  'texas',
#  '.',
#  'graduating',
#  'yale',
#  'university',
#  '1968',
#  'harvard',
#  'business',
#  'school',
#  '1975',
#  ',',
#  'worked',
#  'oil',
#  'industry',
#  '.',
#  'bush',
#  'married',
#  'laura',
#  'welch',
#  '1977',
#  'unsuccessfully',
#  'ran',
#  'u.s.',
#  'house',
#  'representatives',
#  'shortly',
#  'thereafter',
#  '.',
#  'later',
#  'co-owned',
#  'texas',
#  'rangers',
#  'baseball',
#  'team',
#  'defeating',
#  'ann',
#  'richards',
#  '1994',
#  'texas',
#  'gubernatorial',
#  'election',
#  '.',
#  'bush',
#  'elected',
#  'president',
# ...

# %%
len(word_list)
# Out:
# 613

# %%
len(StopWords_removed)
# Out:
# 407

# %%
len(Stop_words)
# Out:
# 179

# %%
#4

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/harshida/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag

# %%
PoS=nltk.pos_tag(StopWords_removed)
PoS
# Out:
# [('george', 'NN'),
#  ('walker', 'NN'),
#  ('bush', 'NN'),
#  ('(', '('),
#  ('born', 'VBN'),
#  ('july', 'RB'),
#  ('6', 'CD'),
#  (',', ','),
#  ('1946', 'CD'),
#  (')', ')'),
#  ('american', 'JJ'),
#  ('politician', 'NN'),
#  ('businessman', 'NN'),
#  ('served', 'VBD'),
#  ('43rd', 'CD'),
#  ('president', 'NN'),
#  ('united', 'VBN'),
#  ('states', 'NNS'),
#  ('2001', 'CD'),
#  ('2009.', 'CD'),
#  ('previously', 'RB'),
#  ('served', 'VBD'),
#  ('46th', 'CD'),
#  ('governor', 'NN'),
#  ('texas', 'NN'),
#  ('1995', 'CD'),
#  ('2000.', 'CD'),
#  ('bush', 'NN'),
#  ('born', 'VBN'),
#  ('new', 'JJ'),
#  (',', ','),
#  ('connecticut', 'NN'),
#  (',', ','),
#  ('grew', 'VBD'),
#  ('texas', 'NN'),
#  ('.', '.'),
#  ('graduating', 'VBG'),
#  ('yale', 'NN'),
#  ('university', 'NN'),
#  ('1968', 'CD'),
#  ('harvard', 'NN'),
#  ('business', 'NN'),
#  ('school', 'NN'),
#  ('1975', 'CD'),
#  (',', ','),
#  ('worked', 'VBD'),
#  ('oil', 'NN'),
#  ('industry', 'NN'),
#  ('.', '.'),
# ...

# %%
PoS1=nltk.pos_tag(StopWords_removed1)
PoS1
# Out:
# [('george', 'NN'),
#  ('walker', 'NN'),
#  ('bush', 'NN'),
#  ('(', '('),
#  ('born', 'VBN'),
#  ('july', 'RB'),
#  ('6', 'CD'),
#  (',', ','),
#  ('1946', 'CD'),
#  (')', ')'),
#  ('american', 'JJ'),
#  ('politician', 'NN'),
#  ('businessman', 'NN'),
#  ('served', 'VBD'),
#  ('43rd', 'CD'),
#  ('president', 'NN'),
#  ('united', 'VBN'),
#  ('states', 'NNS'),
#  ('2001', 'CD'),
#  ('2009.', 'CD'),
#  ('previously', 'RB'),
#  ('served', 'VBD'),
#  ('46th', 'CD'),
#  ('governor', 'NN'),
#  ('texas', 'NN'),
#  ('1995', 'CD'),
#  ('2000.', 'CD'),
#  ('bush', 'NN'),
#  ('born', 'VBN'),
#  ('new', 'JJ'),
#  (',', ','),
#  ('connecticut', 'NN'),
#  (',', ','),
#  ('grew', 'VBD'),
#  ('texas', 'NN'),
#  ('.', '.'),
#  ('graduating', 'VBG'),
#  ('yale', 'NN'),
#  ('university', 'NN'),
#  ('1968', 'CD'),
#  ('harvard', 'NN'),
#  ('business', 'NN'),
#  ('school', 'NN'),
#  ('1975', 'CD'),
#  (',', ','),
#  ('worked', 'VBD'),
#  ('oil', 'NN'),
#  ('industry', 'NN'),
#  ('.', '.'),
# ...

# %%
#5

# %%
from nltk.chunk import RegexpParser

# %%
n_gram=r"n_gram:{<JJ>*<NNP>*<NN>}"

# %%
n_gram_parser=RegexpParser(n_gram)

# %%
Chunks=n_gram_parser.parse(PoS)

# %%
for i in range(0,360,1):
    print(Chunks[i])
    print('---------')
# Out:
# (n_gram george/NN)
# ---------
# (n_gram walker/NN)
# ---------
# (n_gram bush/NN)
# ---------
# ('(', '(')
# ---------
# ('born', 'VBN')
# ---------
# ('july', 'RB')
# ---------
# ('6', 'CD')
# ---------
# (',', ',')
# ---------
# ('1946', 'CD')
# ---------
# (')', ')')
# ---------
# (n_gram american/JJ politician/NN)
# ---------
# (n_gram businessman/NN)
# ---------
# ('served', 'VBD')
# ---------
# ('43rd', 'CD')
# ---------
# (n_gram president/NN)
# ---------
# ('united', 'VBN')
# ---------
# ('states', 'NNS')
# ---------
# ('2001', 'CD')
# ---------
# ('2009.', 'CD')
# ---------
# ('previously', 'RB')
# ---------
# ('served', 'VBD')
# ---------
# ('46th', 'CD')
# ---------
# (n_gram governor/NN)
# ---------
# (n_gram texas/NN)
# ---------
# ('1995', 'CD')
# ---------
# ('2000.', 'CD')
# ---------
# (n_gram bush/NN)
# ---------
# ('born', 'VBN')
# ---------
# ('new', 'JJ')
# ---------
# (',', ',')
# ---------
# (n_gram connecticut/NN)
# ---------
# (',', ',')
# ---------
# ...

# %%
n_gram1=r"n_gram:{<JJ>*<NN>}"

# %%
n_gram_parser1=RegexpParser(n_gram1)

# %%
Chunks1=n_gram_parser1.parse(PoS1)

# %%
for i in range (0,1000,1):
    print(Chunks1[i])
    print('************')
# Out:
# (n_gram george/NN)
# ************
# (n_gram walker/NN)
# ************
# (n_gram bush/NN)
# ************
# ('(', '(')
# ************
# ('born', 'VBN')
# ************
# ('july', 'RB')
# ************
# ('6', 'CD')
# ************
# (',', ',')
# ************
# ('1946', 'CD')
# ************
# (')', ')')
# ************
# (n_gram american/JJ politician/NN)
# ************
# (n_gram businessman/NN)
# ************
# ('served', 'VBD')
# ************
# ('43rd', 'CD')
# ************
# (n_gram president/NN)
# ************
# ('united', 'VBN')
# ************
# ('states', 'NNS')
# ************
# ('2001', 'CD')
# ************
# ('2009.', 'CD')
# ************
# ('previously', 'RB')
# ************
# ('served', 'VBD')
# ************
# ('46th', 'CD')
# ************
# (n_gram governor/NN)
# ************
# (n_gram texas/NN)
# ************
# ('1995', 'CD')
# ************
# ('2000.', 'CD')
# ************
# (n_gram bush/NN)
# ************
# ('born', 'VBN')
# ************
# ('new', 'JJ')
# ************
# ...
